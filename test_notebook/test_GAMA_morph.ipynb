# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import fits

# %%
a = fits.open('./data/GAMA_morph_BDD.fits')

# %%
gama_data = Table.read('./data/GAMA_morph_BDD.fits')

# %%
dcomp = gama_data[(gama_data['FINAL_CLASS'] == 'dBD') | (gama_data['FINAL_CLASS'] == 'cBD')]

# %%
print(len(dcomp))
bt_2 = dcomp[(dcomp['R_NCOMP'] == 2) & (dcomp['R_D_OUTLIER_FLAG'] == 0)]['R_D_BT']
bt_15 = dcomp[(dcomp['R_NCOMP'] == 1.5) & (dcomp['R_P_OUTLIER_FLAG'] == 0)]['R_D_BT']
bt = np.append(bt_2, bt_15)
# Out:
# 5744

# %%
scomp_disc = gama_data[(gama_data['FINAL_CLASS'] == 'D  ')]

# %%
scomp_disc
# Out:
# <Table length=4807>
# R_NCOMP R_S_BDQUAL_FLAG  R_S_RE  ... HUBBLE_TYPE INITIAL_CLASS FINAL_CLASS
# float32      int16      float64  ...    bytes9       bytes3       bytes3
# ------- --------------- -------- ... ----------- ------------- -----------
#     1.0              64  2.01705 ...   Sd-Irr              D           D
#     1.5              64  2.10545 ...   X                   D           D
#  -999.0               9   -999.0 ...   Sd-Irr              D           D
#     1.0               0  1.63417 ...   LBS                 D           D
#     1.0              64  2.39469 ...   Sd-Irr              X           D
#     1.0              64  4.80125 ...   Sd-Irr              D           D
#     1.0               0  4.12748 ...   Sd-Irr              D           D
#     1.0              64  1.03422 ...   LBS                 X           D
#     2.0              64  2.17995 ...   X                   cBD         D
# ...

# %%
d_2 = gama_data[(gama_data['R_NCOMP'] == 2)]

# %%
plt.hist(bt_2)
# Out:
# (array([271., 261., 254., 233., 167., 173., 146.,  76.,  53.,  31.]),
#  array([0.00999767, 0.1070499 , 0.20410214, 0.30115437, 0.3982066 ,
#         0.49525884, 0.59231107, 0.6893633 , 0.78641553, 0.88346777,
#         0.98052   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bt_15)
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 324.,   0.,   0.,   0.,   0.]),
#  array([-999.5, -999.4, -999.3, -999.2, -999.1, -999. , -998.9, -998.8,
#         -998.7, -998.6, -998.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bt)
# Out:
# (array([ 324.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#         1665.]),
#  array([-9.99000000e+02, -8.99001948e+02, -7.99003896e+02, -6.99005844e+02,
#         -5.99007792e+02, -4.99009740e+02, -3.99011688e+02, -2.99013636e+02,
#         -1.99015584e+02, -9.90175320e+01,  9.80520000e-01]),
#  <BarContainer object of 10 artists>)
